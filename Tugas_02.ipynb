# %% [markdown]
# <a href="https://colab.research.google.com/github/LiaDahlia/Tugas-Machine-Learning/blob/main/Tugas_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
path_="/content/drive/My Drive/Machine Learning/Dataset Tugas 02.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6           1800
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# ..      ...       ...            ...
# 65    67500         6          22000
# 66    83000         3          18700
# 67    79500         7          19500
# 68    59000         4          26000
# 69    58700         4          17500
#
# [70 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(dataset['Mileage'],dataset['Sell Price($)'])

# %%
plt.scatter(dataset['Age(yrs)'],dataset['Sell Price($)'])

# %%
X=dataset[['Mileage','Age(yrs)']]
y=dataset['Sell Price($)']

# %%
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# ..      ...       ...
# 65    67500         6
# 66    83000         3
# 67    79500         7
# 68    59000         4
# 69    58700         4
#
# [70 rows x 2 columns]

# %%
y
# Out:
# 0      1800
# 1     34000
# 2     26100
# 3     40000
# 4     31500
#       ...
# 65    22000
# 66    18700
# 67    19500
# 68    26000
# 69    17500
# Name: Sell Price($), Length: 70, dtype: int64

# %%
from sklearn.model_selection import  train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)

# %%
len(X_train)
# Out:
# 42

# %%
len(X_test)
# Out:
# 28

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 49    35000         3
# 54    42000         5
# 40    69500         4
# 32    32000         5
# 0     69000         6
# 33    87500         6
# 60    69000         5
# 15    25400         3
# 16    28000         2
# 11    79000         7
# 65    67500         6
# 47    32400         5
# 34    51000         3
# 68    59000         4
# 10    83000         7
# 52    43500         3
# 51    22000         2
# 20    35000         4
# 44    27300         2
# 21    81000         8
# 12    59000         5
# 42    82000         3
# 37    70000         4
# 43    25000         3
# 2     57000         5
# 50    54000         2
# 46    87500         6
# 18    87600         8
# 66    83000         3
# 53    57000         5
# 63    25450         2
# 3     22500         2
# 17    69000         5
# 24    77000         2
# 5     59000         5
# 29    27000         2
# 56    31000         4
# 64    91000         5
# 25    69000         5
# 23    63000         7
# ...

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 38    65000         7
# 1     35000         3
# 14    82450         7
# 9     67000         6
# 19    52000         5
# 35    25000         6
# 58    53000         7
# 55    72000         2
# 61    58700         4
# 39    52700         2
# 41    48700         3
# 48    68000         6
# 57    37000         2
# 62    82400         7
# 26    48780         3
# 28    25000         3
# 36    81000         5
# 4     46000         4
# 6     52000         5
# 13    58780         4
# 8     91000         8
# 59    79000         8
# 45    68000         2
# 30    68000         5
# 7     72000         6
# 22    77000         5
# 31    87000         8
# 67    79500         7

# %%
y_train
# Out:
# 49    34000
# 54    22000
# 40    26000
# 32    18200
# 0      1800
# 33    22800
# 60    26000
# 15    35000
# 16    35000
# 11    19500
# 65    22000
# 47    28200
# 34    28200
# 68    26000
# 10    18700
# 52    31500
# 51    41000
# 20    14700
# 44    31000
# 21    13000
# 12    26000
# 42    29000
# 37    12000
# 43    33500
# 2     26100
# 50    26000
# 46    22800
# 18    12800
# 66    18700
# 53    16750
# 63    35000
# 3     40000
# 17    19700
# 24    18500
# 5     26750
# 29    31000
# 56    12000
# 64    22000
# 25    16000
# 23    28700
# 69    17500
# 27    29400
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 38    28500
# 1     34000
# 14    19400
# 9     22000
# 19    28200
# 35    24700
# 58    28700
# 55    19300
# 61    27000
# 39    16500
# 41    17500
# 48    18000
# 57    22000
# 62    19500
# 26    27500
# 28    33000
# 36    33000
# 4     31500
# 6     32000
# 13    27500
# 8     12000
# 59    19500
# 45    14700
# 30    12700
# 7     19300
# 22    32000
# 31    22800
# 67    19500
# Name: Sell Price($), dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4, random_state=10)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 23    63000         7
# 60    69000         5
# 61    58700         4
# 65    67500         6
# 18    87600         8
# 27    82400         3
# 31    87000         8
# 1     35000         3
# 12    59000         5
# 57    37000         2
# 39    52700         2
# 30    68000         5
# 22    77000         5
# 66    83000         3
# 44    27300         2
# 25    69000         5
# 46    87500         6
# 5     59000         5
# 13    58780         4
# 14    82450         7
# 55    72000         2
# 67    79500         7
# 33    87500         6
# 43    25000         3
# 24    77000         2
# 11    79000         7
# 47    32400         5
# 58    53000         7
# 16    28000         2
# 51    22000         2
# 36    81000         5
# 54    42000         5
# 40    69500         4
# 42    82000         3
# 0     69000         6
# 69    58700         4
# 8     91000         8
# 29    27000         2
# 28    25000         3
# 64    91000         5
# ...
